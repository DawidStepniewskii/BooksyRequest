# %% [markdown]
# # Neural Networks using Spectograms

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import tensorflow
import os
import cv2
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, LeakyReLU, GlobalAveragePooling2D
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.preprocessing.image import load_img, img_to_array, ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, classification_report
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.applications import ResNet50
from skimage.transform import resize
from keras.applications.resnet50 import preprocess_input

# %% [markdown]
# ## Save spectrograms arrays to file in order to speed up loading data

# %%
mel_spectogram_data = '/content/drive/MyDrive/GoogleCollab/Data/GTZAN/spectrograms/mel_spectrograms'
mfcc_spectogram_data = '/content/drive/MyDrive/GoogleCollab/Data/GTZAN/spectrograms/mfcc_spectrograms'
standard_spectogram_data = '/content/drive/MyDrive/GoogleCollab/Data/GTZAN/spectrograms/standard_spectrograms'

# %%
def load_spectograms(spectogram_data):
  X, y, classes = [], [], []

  for label, genre in enumerate(os.listdir(spectogram_data)):
      classes.append(genre)
      genre_path = os.path.join(spectogram_data, genre)

      if os.path.isdir(genre_path):
          for img_file in os.listdir(genre_path):
              img_path = os.path.join(genre_path, img_file)

              if os.path.isfile(img_path):
                  img = load_img(img_path)
                  img_array = img_to_array(img)
                  X.append(img_array)
                  y.append(genre)

  X = np.array(X)
  y = np.array(y)

  print(X.shape, y.shape, classes)

  return X, y, classes

# %%
mfcc_X, mfcc_y, mfcc_classes = load_spectograms(mfcc_spectogram_data)
mel_X, mel_y, mel_classes = load_spectograms(mel_spectogram_data)
standard_X, standard_y, standard_classes = load_spectograms(standard_spectogram_data)

np.save('X.npy', mfcc_X)
np.save('y.npy', mfcc_y)
np.save('classes.npy', mfcc_classes)

np.save('X.npy', mel_X)
np.save('y.npy', mel_y)
np.save('classes.npy', mel_classes)

np.save('X.npy', standard_X)
np.save('y.npy', standard_y)
np.save('classes.npy', standard_classes)
# Out:
# (999, 308, 465, 1) (999,) ['reggae', 'blues', 'metal', 'country', 'rock', 'hiphop', 'classical', 'jazz', 'disco', 'pop']
# (996, 308, 465, 1) (996,) ['reggae', 'blues', 'metal', 'country', 'rock', 'hiphop', 'classical', 'jazz', 'disco', 'pop']
# (999, 308, 465, 1) (999,) ['reggae', 'blues', 'metal', 'country', 'rock', 'hiphop', 'classical', 'jazz', 'disco', 'pop']

# %% [markdown]
# ## Load spectogram images

# %%
spectogram_dir = '/content/drive/MyDrive/GoogleCollab/Data/GTZAN/spectrograms/mel_spectrograms'

X = np.load(os.path.join(spectogram_dir, 'X.npy'))
y = np.load(os.path.join(spectogram_dir, 'y.npy'))
classes = np.load(os.path.join(spectogram_dir, 'classes.npy'))

print(X.shape, y.shape, classes)
# Out:
# (996, 308, 465, 3) (996,) ['reggae' 'blues' 'metal' 'country' 'rock' 'hiphop' 'classical' 'jazz'
#  'disco' 'pop']

# %% [markdown]
# # Build Neural Network models

# %% [markdown]
# ## NN Model 1

# %%
def create_nn_model_1():
  model = Sequential(name='Model_1')
  model.add(Conv2D(64, 2, activation = 'relu', input_shape = X.shape[1:]))
  model.add(MaxPooling2D(pool_size = (2,2)))
  model.add(Dropout(0.1))
  model.add(Conv2D(128, 2, activation = 'relu'))
  model.add(MaxPooling2D(pool_size = (2,2)))
  model.add(Dropout(0.1))
  model.add(Conv2D(256, 2, activation = 'relu'))
  model.add(MaxPooling2D(pool_size = (4,4)))
  model.add(Dropout(0.1))
  model.add(Conv2D(512, 2, activation = 'relu'))
  model.add(MaxPooling2D(pool_size = (8,8)))
  model.add(Dropout(0.1))

  model.add(Flatten())

  model.add(Dense(2048, activation = 'relu'))
  model.add(Dense(1024, activation = 'relu'))
  model.add(Dense(256, activation = 'relu'))
  model.add(Dense(128, activation = 'relu'))

  model.add(Dense(10, activation = 'softmax'))
  # model.summary()

  return model

# %%
def model_1_compile(model, checkpoint_path):
  model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
  reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.001)
  checkpoint = ModelCheckpoint(filepath=checkpoint_path, monitor='val_accuracy', mode='max', save_best_only=True, verbose=1)

  return model, reduce_lr, checkpoint

# %% [markdown]
# ## NN Model 2

# %%
def create_nn_model_2():
  model = Sequential(name='Model_2')
  model.add(Conv2D(64, 2, activation = 'relu', input_shape = X.shape[1:]))
  model.add(MaxPooling2D(pool_size = (2,2)))
  model.add(Dropout(0.5))
  model.add(Conv2D(32, 2, activation = 'relu'))
  model.add(MaxPooling2D(pool_size = (2,2)))
  model.add(Dropout(0.5))
  model.add(Conv2D(32, 2, activation = 'relu'))
  model.add(MaxPooling2D(pool_size = (2,2)))

  model.add(Flatten())

  model.add(Dense(64, activation = 'relu'))
  model.add(BatchNormalization())
  model.add(Dense(32, activation = 'relu'))
  model.add(BatchNormalization())
  model.add(Dense(16, activation = 'relu'))
  model.add(BatchNormalization())

  model.add(Dense(10, activation = 'softmax'))
  # model.summary()

  return model

# %% [markdown]
# ## NN Model 3

# %%
def create_nn_model_3():
  model = Sequential(name='Model_3')
  model.add(Conv2D(64, (3, 3), input_shape = X.shape[1:], padding="same", activation='relu'))
  model.add(Conv2D(64, (3, 3), strides=(4, 4), padding="same", activation='relu'))
  model.add(Dropout(0.25))
  model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
  model.add(Conv2D(128, (3, 3), strides=(4, 4), padding='same', activation='relu'))
  model.add(Dropout(0.25))

  model.add(Flatten())

  model.add(Dense(1024, activation=LeakyReLU(alpha=0.1)))
  model.add(BatchNormalization())

  model.add(Dense(512, activation=LeakyReLU(alpha=0.1)))
  model.add(BatchNormalization())

  model.add(Dense(256, activation=LeakyReLU(alpha=0.1)))
  model.add(BatchNormalization())

  model.add(Dense(10, activation = 'softmax'))
  # model.summary()

  return model

# %% [markdown]
# ## ResNet50

# %%
def create_nn_model_4():
  resnet = ResNet50(weights='imagenet', include_top=False, classes=10)
  print("ResNet50 layers:",len(resnet.layers))

  model = resnet.output
  model = GlobalAveragePooling2D()(model)
  model = Dense(1024, activation = 'relu')(model)
  model = Dense(512, activation = 'relu')(model)
  last_layer = Dense(10, activation = 'softmax')(model)
  model = Model(name="Model_ResNet50", inputs = resnet.input, outputs = last_layer)

  print("Combined model:",len(model.layers),'layers')

  for layer in model.layers[:175]:
    layer.trainable = False

  for layer in model.layers[175:]:
      layer.trainable = True

  return model

# %%
def resnet_compile(model, checkpoint_path):
  lr_schedule = tensorflow.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=0.0001,
    decay_steps=10000,
    decay_rate=1e-6)

  optimizer = RMSprop(learning_rate=lr_schedule)

  model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
  checkpoint = ModelCheckpoint(filepath=checkpoint_path, monitor='val_accuracy', mode='max', save_best_only=True, verbose=1)

  return model, checkpoint

# %% [markdown]
# # Encode labels & split the data

# %% [markdown]
# ## Encode labels

# %%
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)
y_onehot = to_categorical(y_encoded)
print(y_onehot.shape)
# Out:
# (996, 10)

# %% [markdown]
# ## Split data into test & train sets

# %%
X = preprocess_input(X) # Prepare X-array for ResNet model

X_train, X_test, y_train, y_test = train_test_split(X, y_onehot, test_size=0.2, random_state=42, shuffle=True)
print(X_train.shape, X_test.shape, y_test.shape)
# Out:
# (796, 308, 465, 3) (200, 308, 465, 3) (200, 10)

# %% [markdown]
# # Create subdirectories for checkpoints & compile model

# %%
model = create_nn_model_4()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 0s 0us/step
# ResNet50 layers: 175
# Combined model: 179 layers

# %%
checkpoint_dir = "/content/drive/MyDrive/GoogleCollab/Data/GTZAN/checkpoints/"
checkpoint_subdir = os.path.join(checkpoint_dir, model._name)
if not os.path.exists(checkpoint_subdir):
  os.makedirs(checkpoint_subdir)

checkpoint_path = os.path.join(checkpoint_subdir, "mel_best_model.h5")

# %%
model, checkpoint = resnet_compile(model, checkpoint_path)

# %% [markdown]
# # Train model

# %%
from keras.callbacks import CSVLogger

H = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=30, batch_size=32, callbacks=[checkpoint])
loss, accuracy = model.evaluate(X_test, y_test)
save_history(H)

print(f'Test Loss: {loss:.4f}, Test Accuracy: {accuracy:.4f}')
# Out:
# Epoch 1/30
# 25/25 [==============================] - ETA: 0s - loss: 1.7222 - accuracy: 0.4045
# Epoch 1: val_accuracy improved from -inf to 0.54000, saving model to /content/drive/MyDrive/GoogleCollab/Data/GTZAN/checkpoints/Model_ResNet50/mel_best_model.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 25/25 [==============================] - 35s 1s/step - loss: 1.7222 - accuracy: 0.4045 - val_loss: 1.3805 - val_accuracy: 0.5400
# Epoch 2/30
# 25/25 [==============================] - ETA: 0s - loss: 1.1750 - accuracy: 0.6080
# Epoch 2: val_accuracy improved from 0.54000 to 0.55000, saving model to /content/drive/MyDrive/GoogleCollab/Data/GTZAN/checkpoints/Model_ResNet50/mel_best_model.h5
# 25/25 [==============================] - 10s 411ms/step - loss: 1.1750 - accuracy: 0.6080 - val_loss: 1.3161 - val_accuracy: 0.5500
# Epoch 3/30
# 25/25 [==============================] - ETA: 0s - loss: 0.9937 - accuracy: 0.6847
# Epoch 3: val_accuracy improved from 0.55000 to 0.57000, saving model to /content/drive/MyDrive/GoogleCollab/Data/GTZAN/checkpoints/Model_ResNet50/mel_best_model.h5
# 25/25 [==============================] - 11s 446ms/step - loss: 0.9937 - accuracy: 0.6847 - val_loss: 1.2358 - val_accuracy: 0.5700
# Epoch 4/30
# 25/25 [==============================] - ETA: 0s - loss: 0.8819 - accuracy: 0.7136
# Epoch 4: val_accuracy improved from 0.57000 to 0.59500, saving model to /content/drive/MyDrive/GoogleCollab/Data/GTZAN/checkpoints/Model_ResNet50/mel_best_model.h5
# 25/25 [==============================] - 13s 515ms/step - loss: 0.8819 - accuracy: 0.7136 - val_loss: 1.1896 - val_accuracy: 0.5950
# Epoch 5/30
# 25/25 [==============================] - ETA: 0s - loss: 0.7928 - accuracy: 0.7425
# Epoch 5: val_accuracy improved from 0.59500 to 0.61500, saving model to /content/drive/MyDrive/GoogleCollab/Data/GTZAN/checkpoints/Model_ResNet50/mel_best_model.h5
# 25/25 [==============================] - 10s 410ms/step - loss: 0.7928 - accuracy: 0.7425 - val_loss: 1.1690 - val_accuracy: 0.6150
# Epoch 6/30
# 25/25 [==============================] - ETA: 0s - loss: 0.7284 - accuracy: 0.7714
# Epoch 6: val_accuracy did not improve from 0.61500
# 25/25 [==============================] - 9s 364ms/step - loss: 0.7284 - accuracy: 0.7714 - val_loss: 1.1762 - val_accuracy: 0.6050
# Epoch 7/30
# 25/25 [==============================] - ETA: 0s - loss: 0.6666 - accuracy: 0.7889
# Epoch 7: val_accuracy improved from 0.61500 to 0.65000, saving model to /content/drive/MyDrive/GoogleCollab/Data/GTZAN/checkpoints/Model_ResNet50/mel_best_model.h5
# 25/25 [==============================] - 12s 500ms/step - loss: 0.6666 - accuracy: 0.7889 - val_loss: 1.0497 - val_accuracy: 0.6500
# Epoch 8/30
# 25/25 [==============================] - ETA: 0s - loss: 0.6249 - accuracy: 0.8116
# Epoch 8: val_accuracy did not improve from 0.65000
# 25/25 [==============================] - 10s 402ms/step - loss: 0.6249 - accuracy: 0.8116 - val_loss: 1.0514 - val_accuracy: 0.6250
# Epoch 9/30
# 25/25 [==============================] - ETA: 0s - loss: 0.5836 - accuracy: 0.8216
# Epoch 9: val_accuracy did not improve from 0.65000
# 25/25 [==============================] - 9s 376ms/step - loss: 0.5836 - accuracy: 0.8216 - val_loss: 1.1032 - val_accuracy: 0.6350
# Epoch 10/30
# 25/25 [==============================] - ETA: 0s - loss: 0.5415 - accuracy: 0.8354
# Epoch 10: val_accuracy did not improve from 0.65000
# 25/25 [==============================] - 9s 373ms/step - loss: 0.5415 - accuracy: 0.8354 - val_loss: 1.0325 - val_accuracy: 0.6300
# Epoch 11/30
# 25/25 [==============================] - ETA: 0s - loss: 0.5084 - accuracy: 0.8505
# Epoch 11: val_accuracy improved from 0.65000 to 0.66500, saving model to /content/drive/MyDrive/GoogleCollab/Data/GTZAN/checkpoints/Model_ResNet50/mel_best_model.h5
# 25/25 [==============================] - 12s 481ms/step - loss: 0.5084 - accuracy: 0.8505 - val_loss: 0.9934 - val_accuracy: 0.6650
# Epoch 12/30
# 25/25 [==============================] - ETA: 0s - loss: 0.4763 - accuracy: 0.8580
# Epoch 12: val_accuracy did not improve from 0.66500
# 25/25 [==============================] - 9s 376ms/step - loss: 0.4763 - accuracy: 0.8580 - val_loss: 1.0659 - val_accuracy: 0.6450
# Epoch 13/30
# 25/25 [==============================] - ETA: 0s - loss: 0.4566 - accuracy: 0.8668
# Epoch 13: val_accuracy did not improve from 0.66500
# 25/25 [==============================] - 9s 376ms/step - loss: 0.4566 - accuracy: 0.8668 - val_loss: 1.0224 - val_accuracy: 0.6550
# Epoch 14/30
# 25/25 [==============================] - ETA: 0s - loss: 0.4341 - accuracy: 0.8781
# Epoch 14: val_accuracy did not improve from 0.66500
# 25/25 [==============================] - 10s 397ms/step - loss: 0.4341 - accuracy: 0.8781 - val_loss: 0.9950 - val_accuracy: 0.6600
# Epoch 15/30
# 25/25 [==============================] - ETA: 0s - loss: 0.4103 - accuracy: 0.8832
# Epoch 15: val_accuracy did not improve from 0.66500
# 25/25 [==============================] - 10s 402ms/step - loss: 0.4103 - accuracy: 0.8832 - val_loss: 1.0331 - val_accuracy: 0.6550
# Epoch 16/30
# 25/25 [==============================] - ETA: 0s - loss: 0.3672 - accuracy: 0.9108
# Epoch 16: val_accuracy did not improve from 0.66500
# 25/25 [==============================] - 9s 372ms/step - loss: 0.3672 - accuracy: 0.9108 - val_loss: 1.0367 - val_accuracy: 0.6450
# Epoch 17/30
# 25/25 [==============================] - ETA: 0s - loss: 0.3600 - accuracy: 0.9058
# Epoch 17: val_accuracy did not improve from 0.66500
# 25/25 [==============================] - 10s 396ms/step - loss: 0.3600 - accuracy: 0.9058 - val_loss: 1.1033 - val_accuracy: 0.6450
# Epoch 18/30
# 25/25 [==============================] - ETA: 0s - loss: 0.3473 - accuracy: 0.9108
# Epoch 18: val_accuracy improved from 0.66500 to 0.69500, saving model to /content/drive/MyDrive/GoogleCollab/Data/GTZAN/checkpoints/Model_ResNet50/mel_best_model.h5
# 25/25 [==============================] - 12s 473ms/step - loss: 0.3473 - accuracy: 0.9108 - val_loss: 0.9788 - val_accuracy: 0.6950
# Epoch 19/30
# 25/25 [==============================] - ETA: 0s - loss: 0.3188 - accuracy: 0.9209
# Epoch 19: val_accuracy did not improve from 0.69500
# 25/25 [==============================] - 9s 374ms/step - loss: 0.3188 - accuracy: 0.9209 - val_loss: 0.9727 - val_accuracy: 0.6650
# Epoch 20/30
# 25/25 [==============================] - ETA: 0s - loss: 0.3083 - accuracy: 0.9234
# Epoch 20: val_accuracy did not improve from 0.69500
# 25/25 [==============================] - 10s 405ms/step - loss: 0.3083 - accuracy: 0.9234 - val_loss: 0.9627 - val_accuracy: 0.6550
# Epoch 21/30
# 25/25 [==============================] - ETA: 0s - loss: 0.2948 - accuracy: 0.9171
# Epoch 21: val_accuracy did not improve from 0.69500
# 25/25 [==============================] - 9s 369ms/step - loss: 0.2948 - accuracy: 0.9171 - val_loss: 1.0293 - val_accuracy: 0.6850
# Epoch 22/30
# 25/25 [==============================] - ETA: 0s - loss: 0.2800 - accuracy: 0.9422
# Epoch 22: val_accuracy did not improve from 0.69500
# 25/25 [==============================] - 10s 403ms/step - loss: 0.2800 - accuracy: 0.9422 - val_loss: 0.9984 - val_accuracy: 0.6600
# Epoch 23/30
# 25/25 [==============================] - ETA: 0s - loss: 0.2693 - accuracy: 0.9435
# Epoch 23: val_accuracy did not improve from 0.69500
# 25/25 [==============================] - 9s 376ms/step - loss: 0.2693 - accuracy: 0.9435 - val_loss: 0.9756 - val_accuracy: 0.6400
# Epoch 24/30
# 25/25 [==============================] - ETA: 0s - loss: 0.2468 - accuracy: 0.9497
# Epoch 24: val_accuracy did not improve from 0.69500
# 25/25 [==============================] - 10s 399ms/step - loss: 0.2468 - accuracy: 0.9497 - val_loss: 0.9781 - val_accuracy: 0.6800
# Epoch 25/30
# 25/25 [==============================] - ETA: 0s - loss: 0.2429 - accuracy: 0.9548
# Epoch 25: val_accuracy did not improve from 0.69500
# 25/25 [==============================] - 10s 396ms/step - loss: 0.2429 - accuracy: 0.9548 - val_loss: 0.9985 - val_accuracy: 0.6600
# Epoch 26/30
# 25/25 [==============================] - ETA: 0s - loss: 0.2262 - accuracy: 0.9548
# Epoch 26: val_accuracy did not improve from 0.69500
# 25/25 [==============================] - 9s 375ms/step - loss: 0.2262 - accuracy: 0.9548 - val_loss: 1.0228 - val_accuracy: 0.6700
# Epoch 27/30
# 25/25 [==============================] - ETA: 0s - loss: 0.2261 - accuracy: 0.9523
# Epoch 27: val_accuracy did not improve from 0.69500
# 25/25 [==============================] - 10s 404ms/step - loss: 0.2261 - accuracy: 0.9523 - val_loss: 0.9810 - val_accuracy: 0.6700
# Epoch 28/30
# 25/25 [==============================] - ETA: 0s - loss: 0.2157 - accuracy: 0.9598
# Epoch 28: val_accuracy did not improve from 0.69500
# 25/25 [==============================] - 10s 396ms/step - loss: 0.2157 - accuracy: 0.9598 - val_loss: 1.0036 - val_accuracy: 0.6750
# Epoch 29/30
# 25/25 [==============================] - ETA: 0s - loss: 0.1933 - accuracy: 0.9711
# Epoch 29: val_accuracy did not improve from 0.69500
# 25/25 [==============================] - 9s 368ms/step - loss: 0.1933 - accuracy: 0.9711 - val_loss: 0.9834 - val_accuracy: 0.6850
# Epoch 30/30
# 25/25 [==============================] - ETA: 0s - loss: 0.1955 - accuracy: 0.9648
# Epoch 30: val_accuracy did not improve from 0.69500
# 25/25 [==============================] - 9s 371ms/step - loss: 0.1955 - accuracy: 0.9648 - val_loss: 1.0385 - val_accuracy: 0.6650
# 7/7 [==============================] - 2s 251ms/step - loss: 1.0385 - accuracy: 0.6650
# Test Loss: 1.0385, Test Accuracy: 0.6650

# %%
import shutil

def save_history(history):
  filename = f'{model._name}_history.npy'
  np.save(filename, H.history)
  content_dir = "/content/" + filename
  checkpoint_dir = "/content/drive/MyDrive/GoogleCollab/Data/GTZAN/checkpoints/" + model._name
  shutil.copy(content_dir, checkpoint_dir)

# %% [markdown]
# # Calculate model metrics

# %%
checkpoint_dir = "/content/drive/MyDrive/GoogleCollab/Data/GTZAN/checkpoints/"
models_dict = {}

for directory in os.listdir(checkpoint_dir):
  if directory == "Model_ResNet50":
    X = preprocess_input(X)

  X_train, X_test, y_train, y_test = train_test_split(X, y_onehot, test_size=0.2, random_state=42, shuffle=True)
  best_model_path = os.path.join(checkpoint_dir, directory)
  best_model = tensorflow.keras.models.load_model(best_model_path + "/mel_best_model.h5")

  predict_results = best_model.predict(X_test)

  y_pred = np.argmax(predict_results, axis=1)
  y_test = np.argmax(y_test, axis=1)

  history = f"{checkpoint_dir}{directory}/{directory}_history.npy"

  model_dict = {'y_pred': y_pred, 'y_test': y_test, 'history': history}
  models_dict[str(directory)] = model_dict
# Out:
# 7/7 [==============================] - 1s 78ms/step
# 7/7 [==============================] - 3s 287ms/step

# %%
for model in models_dict:
  y_pred = models_dict.get(model).get('y_pred')
  y_test = models_dict.get(model).get('y_test')
  accuracy = accuracy_score(y_test, y_pred)
  report = classification_report(y_test, y_pred, target_names=classes)
  print(str(model) + " statistics")
  print(report)
  print(f'Accuracy: {accuracy:.4f}' + '\n')
# Out:
# Model_1 statistics
#               precision    recall  f1-score   support
#
#       reggae       0.44      0.50      0.47        14
#        blues       0.83      0.88      0.86        17
#        metal       0.50      0.43      0.47        23
#      country       0.45      0.56      0.50        27
#         rock       0.57      0.52      0.55        23
#       hiphop       0.58      0.58      0.58        12
#    classical       0.91      0.77      0.83        26
#         jazz       0.39      0.61      0.48        18
#        disco       0.47      0.43      0.45        21
#          pop       0.36      0.21      0.27        19
#
#     accuracy                           0.55       200
#    macro avg       0.55      0.55      0.54       200
# weighted avg       0.56      0.55      0.55       200
#
# Accuracy: 0.5500
#
# Model_ResNet50 statistics
#               precision    recall  f1-score   support
#
#       reggae       0.64      0.50      0.56        14
#        blues       0.84      0.94      0.89        17
#        metal       0.63      0.52      0.57        23
#      country       0.51      0.74      0.61        27
#         rock       0.90      0.83      0.86        23
#       hiphop       0.69      0.75      0.72        12
#    classical       0.96      0.85      0.90        26
#         jazz       0.60      0.67      0.63        18
#        disco       0.68      0.62      0.65        21
#          pop       0.50      0.42      0.46        19
#
#     accuracy                           0.69       200
#    macro avg       0.70      0.68      0.68       200
# weighted avg       0.70      0.69      0.69       200
#
# Accuracy: 0.6900

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

for model in models_dict:
  y_pred = models_dict.get(model).get('y_pred')
  y_test = models_dict.get(model).get('y_test')
  cm = confusion_matrix(y_test, y_pred)

  plt.figure(figsize=(8, 6))
  sns.heatmap(cm, annot=True, fmt='d', cmap='inferno', xticklabels=classes, yticklabels=classes)
  plt.title('Correlation Heatmap: ' + str(model))
  plt.xlabel('Predicted')
  plt.ylabel('True')
  plt.show()

# %%
for model in models_dict:
  history = np.load(models_dict.get(model).get('history'), allow_pickle='TRUE').item()
  plot_history(history, model)

# %%
def plot_history(history, model_name):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

    ax1.plot(history['accuracy'], label='Train Accuracy')
    ax1.plot(history['val_accuracy'], label='Validation Accuracy')
    ax1.set_title('Model Accuracy')
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Accuracy')
    ax1.legend(loc='lower right')

    ax2.plot(history['loss'], label='Train Loss')
    ax2.plot(history['val_loss'], label='Validation Loss')
    ax2.set_title('Model Loss')
    ax2.set_xlabel('Epoch')
    ax2.set_ylabel('Loss')
    ax2.legend(loc='upper right')

    fig.suptitle(model_name, fontsize=16)

    plt.tight_layout(rect=[0, 0, 1, 0.95])  # Adjust layout to make room for the main title
    plt.show()
